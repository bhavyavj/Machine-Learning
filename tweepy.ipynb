# %% [markdown]
# <a href="https://colab.research.google.com/github/bhavyavj/Machine-Learning/blob/master/tweepy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tweepy
import time
from textblob import TextBlob
import matplotlib.pyplot as plt

# %%
# all 4 authentication keys to acces twitter api
# to connect as oAuth handeler or jump server /reverse proxy server

consumer_key='o69r3NU2sQIc5k6KRFmA3DjGr'
consumer_sec='X6KFJEJthuwzHI4ahRdqBEPOcnCl4qO0QGGp2QoVybV8acVoab'

'''#{
  "consumer_key": "o69r3NU2sQIc5k6KRFmA3DjGr",
  "consumer_secret": "X6KFJEJthuwzHI4ahRdqBEPOcnCl4qO0QGGp2QoVybV8acVoab",
  "access_token": "974243592100196352-9PvW5ADR9P3fSESt7muEXuHMRZFIUa0",
  "access_token_secret": "IVqnWFLt6Mp2JMlJw4CqRMZGpXeNoOTvDoTXmydz5qDES"
}'''

access_token='974243592100196352-9PvW5ADR9P3fSESt7muEXuHMRZFIUa0'
access_sec='IVqnWFLt6Mp2JMlJw4CqRMZGpXeNoOTvDoTXmydz5qDES'

# %%
#tweepy explore
#connecting to jump server of twitter 
auth=tweepy.OAuthHandler(consumer_key,consumer_sec)

# %%
#now we can connect from jump server to web server of twitter
auth.set_access_token(access_token,access_sec)

# %%
#now we can connect to API storage server of twitter
api_connect=tweepy.API(auth)

# %%
tweet_data=api_connect.search('virat',count=100) #now you can search any data from twitter

# %%
pos=0
neg=0
neu=0
for tweet in tweet_data:
  print(tweet.text)
  print("--"*10)
  analysis=TextBlob(tweet.text) # here it will apply nlp
#  print(analysis.sentiment())
  #now checking polarity
  if analysis.sentiment.polarity > 0:
    print('positive')
    print("--"*20)
    pos=pos+1
  elif analysis.sentiment.polarity == 0:
    print('neutral')
    print("--"*20)
    neu=neu+1
  else:
    print('negative')
    print("--"*20)
    neg=neg+1
    
    
#ploting graphs
plt.xlabel("tags")
plt.ylabel("polarity")
#plt.bar(['pos','neg','neu'],[pos,neg,neu])
plt.pie([pos,neg,neu],labels=['pos','neg','neu'],autopct="%1.1f")
plt.show()
# Out:
# @imVkohli 💞💞💞💞💞💞💞💞💞💞💞💞💞💞💞💞💞💞💞💞💞💞💞😘😘😘😘😘😘😘😘🇮🇳🇮🇳🇮🇳🇮🇳🇮🇳🇮🇳🇮🇳🇮🇳🇮🇳🇮🇳💪💪💪💪🙏🙏💪💪🙏🙏🙏🙏 Love U Virat 😊
# --------------------
# positive
# ----------------------------------------
# RT @Cric_beat: Most ODI 100s in the last year
# 9 Rohit
# 6 Virat
#
# Most 100s in the last 2 years
# 15 Rohit
# 14 Virat
#
# Most 100s in the last 3…
# --------------------
# positive
# ----------------------------------------
# @sportsrapid_ Virat Kohli will score maximum fours (4s)
# #SLvsIND #cricket #worldcup #icc #cricketworldcup… https://t.co/yorw15VBit
# --------------------
# neutral
# ----------------------------------------
# @Housing Virat Kohli
# #BringTheCupHome @Housing @saya_sonam @blessedkamal @BhumikaDhawan1 @SayyedJenifer @SonamjitKaur
# --------------------
# neutral
# ----------------------------------------
# Is this cosmic justice? The sasta Virat Kohli type character in this film is called AKHIL SOOD.
#
# There is a god @akhilsoodsood.
# --------------------
# neutral
# ...
