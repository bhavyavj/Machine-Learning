# %% [markdown]
# <a href="https://colab.research.google.com/github/bhavyavj/Machine-Learning/blob/master/open_cv_p.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('00-puppy.jpg')
type(img)
# Out:
# numpy.ndarray

# %%
 img.shape
#cv2.waitKey(30)
# Out:
# (1300, 1950, 3)

# %%
plt.imshow(img)

# %%
# MATPLOTLIB ---> RGB
# OPEN CV ----> BGR

# %%
fix=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix)

# %%
img_g=cv2.imread('00-puppy.jpg',cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(img_g,cmap='gray')

# %%
plt.imshow(fix)

# %%
fix.shape
# Out:
# (1300, 1950, 3)

# %%
new=cv2.resize(fix,(1000,400))

# %%
plt.imshow(new)

# %%
w_rat=0.8
h_rat=0.2

# %%
new=cv2.resize(fix,(0,0),fix,w_rat,h_rat)

# %%
plt.imshow(new)

# %%
new.shape
# Out:
# (260, 1560, 3)

# %%
new_img=cv2.flip(fix,-1)
plt.imshow(new_img)

# %%
 cv2.imwrite('coins_on_white.jpg',fix)
# Out:
# True

# %%
fig=plt.figure(figsize=(10,10))

# %%
ax=fig.add_subplot(111)

# %%
ax.imshow(fix)

# %%
ax.imshow(fix)
